# %% [markdown]
# # discharge notes

# %%
#configure for local eicu databse
import nltk
import os
os.chdir('/Users/grovesdixon/gitreps/Insight_fellowship_project/')
exec(open("./merge/configure_mimic.py").read())
# Out:
# Configured for local MIMIC database:
# 	user = postgres
# 	dbname = mimic
# 	host = localhost
# 	schema_name = mimiciii
# 	query_schema = SET search_path to mimiciii;

# %% [markdown]
# ### load noteevents

# %%
query = query_schema + 'select * from noteevents'

query = query_schema + """
select 
    hadm_id,
    text
from noteevents
where category = 'Discharge summary';
"""

df = pd.read_sql_query(query,con)
df.head()
# Out:
#    hadm_id                                               text
# 0   167853  Admission Date:  [**2151-7-16**]       Dischar...
# 1   107527  Admission Date:  [**2118-6-2**]       Discharg...
# 2   167118  Admission Date:  [**2119-5-4**]              D...
# 3   196489  Admission Date:  [**2124-7-21**]              ...
# 4   135453  Admission Date:  [**2162-3-3**]              D...

# %% [markdown]
# ### clean the text

# %%
ctext = df['text']
ctext = pd.Series([x.lower() for x in ctext])
replacements = {'\[\*\*.*\*\*\]': 'REMOVEDTEXT',
               '\n': ' '}
ctext = ctext.replace(replacements, regex=True)
df['text'] = ctext
df.head()
# Out:
#    hadm_id                                               text
# 0   167853  admission date:  REMOVEDTEXT   service: addend...
# 1   107527  admission date:  REMOVEDTEXT  date of birth:  ...
# 2   167118  admission date:  REMOVEDTEXT   service: cardio...
# 3   196489  admission date:  REMOVEDTEXT   service: medici...
# 4   135453  admission date:  REMOVEDTEXT  date of birth:  ...

# %% [markdown]
# ### call presence of elements

# %%
#set up list of elements found in the discharge notes
element_list = ['admission date:',
                'chief complaint:',
                'sex:',
               'history of present illness:']


#split out the text elements
tdat = df.loc[:,['hadm_id'].copy()]
for e in element_list:
    #first assign presence absence
    print('{}...'.format(e))
    pa_col = e.replace(':', '') + '_presnt'
    df[pa_col] = df['text'].str.contains(e).astype(int)
    print('\t{} instances detected out of {} rows'.format(np.sum(df[pa_col]), df.shape[0]))
df.head()
# Out:
# admission date:...
# 	59585 instances detected out of 59652 rows
# chief complaint:...
# 	41370 instances detected out of 59652 rows
# sex:...
# 	51905 instances detected out of 59652 rows
# history of present illness:...
# 	50578 instances detected out of 59652 rows
#    hadm_id                                               text  \
# 0   167853  admission date:  REMOVEDTEXT   service: addend...
# 1   107527  admission date:  REMOVEDTEXT  date of birth:  ...
# 2   167118  admission date:  REMOVEDTEXT   service: cardio...
# 3   196489  admission date:  REMOVEDTEXT   service: medici...
# 4   135453  admission date:  REMOVEDTEXT  date of birth:  ...
#
#    admission date_presnt  chief complaint_presnt  sex_presnt  \
# 0                      1                       0           0
# 1                      1                       0           1
# 2                      1                       1           0
# 3                      1                       1           0
# ...

# %% [markdown]
# # get word frequencies

# %%
#prepare data
tdat = df.loc[:,['hadm_id', 'text']].copy()
tdat.index = tdat['hadm_id']
tdat = tdat.loc[~tdat.index.duplicated(keep='first')]

# %% [markdown]
# ### get tokens

# %%
from nltk.corpus import stopwords

#function to generate and clean the tokens
def clean_tokens(x):
    x=pd.Series(x.split(), dtype='object')
    return list(x[~x.isin(stopwords.words('english'))])

#tokenize
token_df = tdat.copy()
token_df['text'] = token_df['text'].apply(clean_tokens) 
token_df

#gather word count as a feature
wc_df = token_df.copy()
wc_df['wc'] = wc_df['text'].apply(len)
wc_df = wc_df.drop('text', 1)

# %% [markdown]
# ### get word frequencies

# %%
#get word frequencies
print('getting frequencies...')
freq_df = token_df.copy()
freq_df['text'] = freq_df['text'].apply(nltk.FreqDist)
freq_df.head()
# Out:
# getting frequencies...
#          hadm_id                                               text
# hadm_id
# 167853    167853  {'admission': 1, 'date:': 1, 'REMOVEDTEXT': 5,...
# 107527    107527  {'admission': 2, 'date:': 1, 'REMOVEDTEXT': 21...
# 167118    167118  {'admission': 2, 'date:': 1, 'REMOVEDTEXT': 35...
# 196489    196489  {'admission': 2, 'date:': 1, 'REMOVEDTEXT': 30...
# 135453    135453  {'admission': 2, 'date:': 1, 'REMOVEDTEXT': 17...

# %% [markdown]
# ### format into long df

# %%
#build dataframe cor column
c='text'
fdf_list = []
for i in freq_df.index:
    sub_df = pd.DataFrame.from_dict(freq_df.loc[i,c], orient='index')
    sub_df['hadm_id'] = i
    fdf_list.append(sub_df)
fdat = pd.concat(fdf_list)
fdat.columns = ['count', 'hadm_id']
fdat['word'] = fdat.index

# %%
sub = fdat.loc[fdat['hadm_id']==167853,:]
sub
# Out:
#                        count  hadm_id                   word
# admission                  1   167853              admission
# date:                      1   167853                  date:
# REMOVEDTEXT                5   167853            REMOVEDTEXT
# service:                   1   167853               service:
# addendum:                  1   167853              addendum:
# radiologic                 2   167853             radiologic
# studies:                   1   167853               studies:
# studies                    1   167853                studies
# also                       2   167853                   also
# included                   1   167853               included
# chest                      1   167853                  chest
# ct,                        1   167853                    ct,
# confirmed                  1   167853              confirmed
# cavitary                   1   167853               cavitary
# ...

# %% [markdown]
# ### select words based on content and frequency

# %%
word_counts = fdat['word'].value_counts()
print('starting total words = {}'.format(len(word_counts)))
keep = word_counts.index[(word_counts > 25) & (word_counts < 10000)].to_series()
word_lengths = keep.str.len()
keep = keep[word_lengths>3]
keep = keep[~keep.str.contains('[^\w]')]
keep = keep[~keep.str.contains('[\d]')]
keep = keep[~keep.str.contains('__')]
keep = keep[~keep.str.contains('REMOVEDTEXT')]

print('total words appearing kept = {}'.format(len(keep)))
common_fdat = fdat.loc[fdat['word'].isin(keep),:]
common_fdat.head()
# Out:
# starting total words = 664701
# total words appearing kept = 14088
#             count  hadm_id        word
# radiologic      2   167853  radiologic
# studies         1   167853     studies
# included        1   167853    included
# confirmed       1   167853   confirmed
# cavitary        1   167853    cavitary

# %% [markdown]
# ### pivot and convert to present absence

# %%
res = common_fdat.pivot(index='hadm_id', columns='word', values='count')
res
# Out:
# word     abacavir  abandoned  abated  abbreviated  abcess  abcesses  abdm  \
# hadm_id
# 100001        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 100003        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 100006        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 100007        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 100009        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# ...           ...        ...     ...          ...     ...       ...   ...
# 199993        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 199994        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 199995        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 199998        NaN        NaN     NaN          NaN     NaN       NaN   NaN
# 199999        NaN        NaN     NaN          NaN     NaN       NaN   NaN
#
# ...

# %%
pa_dat = res.notna().astype(int)
pa_dat.head()
# Out:
# word     abacavir  abandoned  abated  abbreviated  abcess  abcesses  abdm  \
# hadm_id
# 100001          0          0       0            0       0         0     0
# 100003          0          0       0            0       0         0     0
# 100006          0          0       0            0       0         0     0
# 100007          0          0       0            0       0         0     0
# 100009          0          0       0            0       0         0     0
#
# word     abdom  abdomenal  abdominial  ...  zones  zonisamide  zoster  zosyn  \
# hadm_id                                ...
# 100001       0          0           0  ...      0           0       0      0
# 100003       0          0           0  ...      0           0       0      0
# 100006       0          0           0  ...      0           0       0      0
# 100007       0          0           0  ...      0           0       0      0
# 100009       0          0           0  ...      0           0       0      0
#
# ...

# %% [markdown]
# ### plot word counts

# %%
word_counts[keep].head()
plt.hist(word_counts[keep], bins=1000)
plt.xlim([0,1000])
plt.xlabel('word count accross discharge reports')
plt.ylabel('N words')
plt.show()
print(max(word_counts[keep]))
# Out:
# 9986

# %% [markdown]
# ### write out

# %%
#pa_dat.to_csv('/Users/grovesdixon/projects/Insight/icu_project/my_mimic/discharge_report_word_presence.csv')

# %% [markdown]
# # predict

# %%
#load outcome data
RAND_SEED=1234
N_JOBS=6
odat = pd.read_csv("~/projects/Insight/icu_project/my_mimic/any_readmission.csv")
odat = odat.loc[:,['outcome', 'HADM_ID']].drop_duplicates()
odat.columns = ['y', 'HADM_ID']
odat.index = odat['HADM_ID']
odat = odat.drop('HADM_ID', 1)
odat.shape
# Out:
# (49693, 1)

# %% [markdown]
# ### cbind them

# %%
pa_dat['HADM_ID'] = pa_dat.index
pa_dat = pa_dat.drop('HADM_ID', 1)
shared_ids = pa_dat.index.intersection(odat.index)
left = odat.loc[shared_ids,:]
right = pa_dat.loc[shared_ids,:]
sdat = pd.concat([left, right], axis=1)
sdat.head()
# Out:
#         y  abacavir  abandoned  abated  abbreviated  abcess  abcesses  abdm  \
# 100001  0         0          0       0            0       0         0     0
# 100007  0         0          0       0            0       0         0     0
# 100009  0         0          0       0            0       0         0     0
# 100010  0         0          0       0            0       0         0     0
# 100011  0         0          0       0            0       0         0     0
#
#         abdom  abdomenal  ...  zones  zonisamide  zoster  zosyn  zydis  \
# 100001      0          0  ...      0           0       0      0      0
# 100007      0          0  ...      0           0       0      0      0
# 100009      0          0  ...      0           0       0      0      0
# 100010      0          0  ...      0           0       0      0      0
# 100011      0          0  ...      0           0       0      0      0
#
#         zygoma  zygomatic  zyprexa  zyrtec  zyvox
# ...

# %%
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
y = sdat['y']
X = sdat.drop(['y'], 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=321)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)

#train
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#performance on the training set
exec(open("./merge/my_functions.py").read())
probs_train = log_reg.predict_proba(X_train)
scores_train = probs_train[:, 1]
train_perf = get_model_performance('logistic regression training set', X_train, scores_train, y_train, pos_label=1)
# Out:
# Confusion matrix for threshold = 0.25:
# [[33454    36]
#  [   37  1759]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     33490
#            1       0.98      0.98      0.98      1796
#
#     accuracy                           1.00     35286
#    macro avg       0.99      0.99      0.99     35286
# weighted avg       1.00      1.00      1.00     35286

# %%
#performance on the test set
probs_test = log_reg.predict_proba(X_test)
scores_test = probs_test[:, 1]
test_perf = get_model_performance('logistic regression test set', X_test, scores_test, y_test, pos_label=1)
# Out:
# Confusion matrix for threshold = 0.4:
# [[8009  378]
#  [ 379   56]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      8387
#            1       0.13      0.13      0.13       435
#
#     accuracy                           0.91      8822
#    macro avg       0.54      0.54      0.54      8822
# weighted avg       0.91      0.91      0.91      8822

# %%
#------- OPTIMIZE RF

# # #use RandomizedSearchCV() to optimized Random forest hyperparameters
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import RandomizedSearchCV
# rf_clf = RandomForestClassifier()

# #choose parameter grid values
# max_depth = [10, 50, 100, 150]
# min_samples_split = [1, 3, 5]
# min_samples_leaf = [1, 2, 3]

# #make grid dict
# random_grid = {'max_depth': max_depth,
#                'min_samples_split': min_samples_split,
#                'min_samples_leaf': min_samples_leaf}


# # ### run random search
# rf_search = RandomizedSearchCV(estimator = rf_clf,
#                                param_distributions = random_grid,
#                                n_iter = 50,
#                                scoring = 'recall',
#                                cv = 5,
#                                verbose=2,
#                                random_state=RAND_SEED,
#                                n_jobs = N_JOBS)
# rf_search.fit(X_train, y_train)
# best_params = rf_search.best_params_
# print(rf_search.best_params_)


# #or just select the best parameters if already run
# best_params = {'min_samples_split': 10,
#   'min_samples_leaf': 5,
#   'max_features': 'sqrt',
#   'max_depth': 100,
#   'bootstrap': True}

# print('Best parameters:')
# print(best_params)

# %%
best_params={'min_samples_split': 3, 'min_samples_leaf': 1, 'max_depth': 100}

# %%
#set up optimized rf model based on from best_params above
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
print(best_params)
rf_opt_basic = RandomForestClassifier(n_jobs=N_JOBS,
                                min_samples_split = best_params['min_samples_split'],
                                min_samples_leaf = best_params['min_samples_leaf'],
                                max_depth = best_params['max_depth'],
                                bootstrap = True,
                               random_state=RAND_SEED)

#train
rf_opt_basic.fit(X_train, y_train)
# Out:
# {'min_samples_split': 3, 'min_samples_leaf': 1, 'max_depth': 100}
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=100, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=3,
#                        min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=6,
#                        oob_score=False, random_state=1234, verbose=0,
#                        warm_start=False)

# %%
#optimized model performance on training set
scores_opt = rf_opt_basic.predict_proba(X_train)[:, 1]
opt_perf = get_model_performance('optimized random forest training', X_train, scores_opt, y_train, pos_label=1)
# Out:
# Confusion matrix for threshold = 0.16:
# [[33475    15]
#  [   16  1780]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     33490
#            1       0.99      0.99      0.99      1796
#
#     accuracy                           1.00     35286
#    macro avg       1.00      1.00      1.00     35286
# weighted avg       1.00      1.00      1.00     35286

# %%
#predict for test set
test_scores = rf_opt_basic.predict_proba(X_test)[:, 1]
test_perf = get_model_performance('optimized random forest TEST', X_test, test_scores, y_test, pos_label=1)


threshold = 0.075
opt_pred = (test_scores > threshold).astype('int')
y_num = (y_test==1).astype('int')
print('Confusion matrix for threshold = {}:'.format(round(threshold, 2)))
cm = confusion_matrix(y_num, opt_pred)
print(cm)
print('Classification report:')
print(classification_report(y_num, opt_pred))
# Out:
# Confusion matrix for threshold = 0.12:
# [[8006  381]
#  [ 382   53]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      8387
#            1       0.12      0.12      0.12       435
#
#     accuracy                           0.91      8822
#    macro avg       0.54      0.54      0.54      8822
# weighted avg       0.91      0.91      0.91      8822
# Confusion matrix for threshold = 0.07:
# [[7005 1382]
#  [ 290  145]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.84      0.89      8387
#            1       0.09      0.33      0.15       435
#
#     accuracy                           0.81      8822
#    macro avg       0.53      0.58      0.52      8822
# weighted avg       0.92      0.81      0.86      8822

# %% [markdown]
# ### assess variable importance

# %%
odat
# Out:
#          y
# HADM_ID
# 165315   0
# 152223   0
# 124321   0
# 161859   0
# 129635   0
# ...     ..
# 190603   0
# 191113   0
# 122631   0
# 170407   0
# 190264   0
#
# [49693 rows x 1 columns]

# %%
#pull out feature importance
idat = pd.DataFrame({'feature':X_train.columns,
                     'importance':rf_opt_basic.feature_importances_})
#plot hist
plt.hist(idat['importance'], color = "grey")
plt.xlabel('feature importance')
plt.ylabel('feature count')
plt.show()

#gather important
important_dat = idat.loc[idat['importance']>0.0003,:]
print(important_dat.shape)
important_dat.head()

#plot most important feature
m = max(idat['importance'])
most = idat.loc[idat['importance']>0.0008,:]
most_dat = pa_dat.loc[:,most['feature']]
most_dat['HADM_ID'] = most_dat.index
most_dat = pd.merge(most_dat, odat, how='inner', on='HADM_ID')
most_dat.to_csv('~/Desktop/word_freqs.csv', index=False)
# Out:
# (225, 2)

# %% [markdown]
# ### write out data for important predictors

# %%
ipa_dat = pa_dat.loc[:, important_dat['feature']]
ipa_dat
# Out:
# word     acid  active  adhere  admissions  aerosol  afib  aliskiren  \
# hadm_id
# 100001      0       0       0           1        0     0          0
# 100003      1       0       0           0        0     0          0
# 100006      0       1       0           0        0     0          0
# 100007      0       0       0           0        0     0          0
# 100009      0       0       0           0        0     0          0
# ...       ...     ...     ...         ...      ...   ...        ...
# 199993      0       0       0           0        0     0          0
# 199994      0       0       0           1        0     0          0
# 199995      0       0       0           0        0     0          0
# 199998      0       0       0           0        0     0          0
# 199999      0       0       0           0        0     0          0
#
# word     amiodarone  amount  anemia  ...  unchanged  uveitis  varices  vein  \
# hadm_id                              ...
# ...

# %%
ipa_dat.to_csv('/Users/grovesdixon/projects/Insight/icu_project/my_mimic/selected_nlp_data.csv')
